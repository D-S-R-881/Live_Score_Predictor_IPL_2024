# %%
import pandas as pd

# %%
df_old = pd.read_csv('ipl_match_ball_by_ball_data.csv')
# Out:
# <ipython-input-2-c11ea0e44277>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_old = pd.read_csv('ipl_match_ball_by_ball_data.csv')

# %%
df_2023 = pd.read_csv('ipl_match_ball_by_ball_data_2023.csv')

# %%
df_old.head()
# Out:
#    match_id   season  start_date                  venue  innings  ball  \
# 0    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.1
# 1    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.2
# 2    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.3
# 3    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.4
# 4    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.5
#
#             batting_team                 bowling_team      striker  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
#
#    non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# ...

# %%
df_2023.head()
# Out:
#    match_id  season  start_date                             venue  innings  \
# 0   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 1   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 2   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 3   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 4   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
#
#    ball         batting_team    bowling_team     striker non_striker  ...  \
# 0   0.1  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
# 1   0.2  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
# 2   0.3  Chennai Super Kings  Gujarat Titans  RD Gaikwad   DP Conway  ...
# 3   0.4  Chennai Super Kings  Gujarat Titans  RD Gaikwad   DP Conway  ...
# 4   0.5  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
#
#   extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
df = pd.concat([df_old,df_2023],ignore_index = True, sort = False)

# %%
df
# Out:
#         match_id   season  start_date                             venue  \
# 0         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 1         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 2         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 3         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 4         335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# ...          ...      ...         ...                               ...
# 243812   1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243813   1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243814   1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243815   1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 243816   1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball           batting_team                 bowling_team  \
# ...

# %%
df.drop(['season','start_date','striker','non_striker','bowler','penalty','wicket_type','other_wicket_type','other_player_dismissed'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#    match_id                  venue  innings  ball           batting_team  \
# 0    335982  M Chinnaswamy Stadium        1   0.1  Kolkata Knight Riders
# 1    335982  M Chinnaswamy Stadium        1   0.2  Kolkata Knight Riders
# 2    335982  M Chinnaswamy Stadium        1   0.3  Kolkata Knight Riders
# 3    335982  M Chinnaswamy Stadium        1   0.4  Kolkata Knight Riders
# 4    335982  M Chinnaswamy Stadium        1   0.5  Kolkata Knight Riders
#
#                   bowling_team  runs_off_bat  extras  wides  noballs  byes  \
# 0  Royal Challengers Bangalore             0       1    NaN      NaN   NaN
# 1  Royal Challengers Bangalore             0       0    NaN      NaN   NaN
# 2  Royal Challengers Bangalore             0       1    1.0      NaN   NaN
# 3  Royal Challengers Bangalore             0       0    NaN      NaN   NaN
# 4  Royal Challengers Bangalore             0       0    NaN      NaN   NaN
#
#    legbyes player_dismissed
# 0      1.0              NaN
# ...

# %%
df[['wides','noballs','byes','legbyes','player_dismissed']] = df[['wides','noballs','byes','legbyes','player_dismissed']].fillna(0)
df.head()
# Out:
#    match_id                  venue  innings  ball           batting_team  \
# 0    335982  M Chinnaswamy Stadium        1   0.1  Kolkata Knight Riders
# 1    335982  M Chinnaswamy Stadium        1   0.2  Kolkata Knight Riders
# 2    335982  M Chinnaswamy Stadium        1   0.3  Kolkata Knight Riders
# 3    335982  M Chinnaswamy Stadium        1   0.4  Kolkata Knight Riders
# 4    335982  M Chinnaswamy Stadium        1   0.5  Kolkata Knight Riders
#
#                   bowling_team  runs_off_bat  extras  wides  noballs  byes  \
# 0  Royal Challengers Bangalore             0       1    0.0      0.0   0.0
# 1  Royal Challengers Bangalore             0       0    0.0      0.0   0.0
# 2  Royal Challengers Bangalore             0       1    1.0      0.0   0.0
# 3  Royal Challengers Bangalore             0       0    0.0      0.0   0.0
# 4  Royal Challengers Bangalore             0       0    0.0      0.0   0.0
#
#    legbyes player_dismissed
# 0      1.0                0
# ...

# %%
df['runs_scored'] = df['runs_off_bat'] + df['extras']

# %%
df.head()
# Out:
#    match_id                  venue  innings  ball           batting_team  \
# 0    335982  M Chinnaswamy Stadium        1   0.1  Kolkata Knight Riders
# 1    335982  M Chinnaswamy Stadium        1   0.2  Kolkata Knight Riders
# 2    335982  M Chinnaswamy Stadium        1   0.3  Kolkata Knight Riders
# 3    335982  M Chinnaswamy Stadium        1   0.4  Kolkata Knight Riders
# 4    335982  M Chinnaswamy Stadium        1   0.5  Kolkata Knight Riders
#
#                   bowling_team  runs_off_bat  extras  wides  noballs  byes  \
# 0  Royal Challengers Bangalore             0       1    0.0      0.0   0.0
# 1  Royal Challengers Bangalore             0       0    0.0      0.0   0.0
# 2  Royal Challengers Bangalore             0       1    1.0      0.0   0.0
# 3  Royal Challengers Bangalore             0       0    0.0      0.0   0.0
# 4  Royal Challengers Bangalore             0       0    0.0      0.0   0.0
#
#    legbyes player_dismissed  runs_scored
# ...

# %%
df.drop(['runs_off_bat','extras','wides','noballs','byes','legbyes'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#    match_id                  venue  innings  ball           batting_team  \
# 0    335982  M Chinnaswamy Stadium        1   0.1  Kolkata Knight Riders
# 1    335982  M Chinnaswamy Stadium        1   0.2  Kolkata Knight Riders
# 2    335982  M Chinnaswamy Stadium        1   0.3  Kolkata Knight Riders
# 3    335982  M Chinnaswamy Stadium        1   0.4  Kolkata Knight Riders
# 4    335982  M Chinnaswamy Stadium        1   0.5  Kolkata Knight Riders
#
#                   bowling_team player_dismissed  runs_scored
# 0  Royal Challengers Bangalore                0            1
# 1  Royal Challengers Bangalore                0            0
# 2  Royal Challengers Bangalore                0            1
# 3  Royal Challengers Bangalore                0            0
# 4  Royal Challengers Bangalore                0            0

# %%
df.head()
# Out:
#    match_id                  venue  innings  ball           batting_team  \
# 0    335982  M Chinnaswamy Stadium        1   0.1  Kolkata Knight Riders
# 1    335982  M Chinnaswamy Stadium        1   0.2  Kolkata Knight Riders
# 2    335982  M Chinnaswamy Stadium        1   0.3  Kolkata Knight Riders
# 3    335982  M Chinnaswamy Stadium        1   0.4  Kolkata Knight Riders
# 4    335982  M Chinnaswamy Stadium        1   0.5  Kolkata Knight Riders
#
#                   bowling_team player_dismissed  runs_scored
# 0  Royal Challengers Bangalore                0            1
# 1  Royal Challengers Bangalore                0            0
# 2  Royal Challengers Bangalore                0            1
# 3  Royal Challengers Bangalore                0            0
# 4  Royal Challengers Bangalore                0            0

# %%
df
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243812   1370353  Narendra Modi Stadium, Ahmedabad        2  14.2
# 243813   1370353  Narendra Modi Stadium, Ahmedabad        2  14.3
# 243814   1370353  Narendra Modi Stadium, Ahmedabad        2  14.4
# 243815   1370353  Narendra Modi Stadium, Ahmedabad        2  14.5
# 243816   1370353  Narendra Modi Stadium, Ahmedabad        2  14.6
#
#                  batting_team                 bowling_team player_dismissed  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                0
# ...

# %%
df_new = df[df['innings']==1]
df_new
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# 243719   1370353  Narendra Modi Stadium, Ahmedabad        1  19.3
# 243720   1370353  Narendra Modi Stadium, Ahmedabad        1  19.4
# 243721   1370353  Narendra Modi Stadium, Ahmedabad        1  19.5
# 243722   1370353  Narendra Modi Stadium, Ahmedabad        1  19.6
#
#                  batting_team                 bowling_team player_dismissed  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                0
# ...

# %%
df_new['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Mumbai Indians', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
df_new.loc[(df_new.batting_team == 'Deccan Chargers'),'batting_team']='Sunrisers Hyderabad'
df_new.loc[(df_new.batting_team == 'Kings XI Punjab'),'batting_team']='Punjab Kings'
df_new.loc[(df_new.batting_team == 'Delhi Daredevils'),'batting_team']='Delhi Capitals'
df_new.loc[(df_new.batting_team == 'Royal Challengers Bangalore'),'batting_team']='Royal Challengers Bangaluru'

df_new['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Punjab Kings',
#        'Royal Challengers Bangaluru', 'Delhi Capitals',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Lucknow Super Giants',
#        'Gujarat Titans'], dtype=object)

# %%
df_new.loc[(df_new.bowling_team == 'Deccan Chargers'),'bowling_team']='Sunrisers Hyderabad'
df_new.loc[(df_new.bowling_team == 'Kings XI Punjab'),'bowling_team']='Punjab Kings'
df_new.loc[(df_new.bowling_team == 'Delhi Daredevils'),'bowling_team']='Delhi Capitals'
df_new.loc[(df_new.bowling_team == 'Royal Challengers Bangalore'),'bowling_team']='Royal Challengers Bangaluru'

df_new['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Sunrisers Hyderabad', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Gujarat Titans', 'Lucknow Super Giants'],
#       dtype=object)

# %%
teams = ['Kolkata Knight Riders','Chennai Super Kings','Rajasthan Royals','Mumbai Indians','Punjab Kings',
          'Delhi Capitals','Gujarat Titans','Lucknow Super Giants','Sunrisers Hyderabad','Royal Challengers Bangaluru']

# %%
df_new = df_new[df_new['batting_team'].isin(teams)]
df_new = df_new[df_new['bowling_team'].isin(teams)]

# %%
df_new['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Punjab Kings',
#        'Royal Challengers Bangaluru', 'Delhi Capitals',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
df_new
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# 243719   1370353  Narendra Modi Stadium, Ahmedabad        1  19.3
# 243720   1370353  Narendra Modi Stadium, Ahmedabad        1  19.4
# 243721   1370353  Narendra Modi Stadium, Ahmedabad        1  19.5
# 243722   1370353  Narendra Modi Stadium, Ahmedabad        1  19.6
#
#                  batting_team                 bowling_team player_dismissed  \
# 0       Kolkata Knight Riders  Royal Challengers Bangaluru                0
# ...

# %%
# Considering these 8 parameters for final score prediction
# batting_team
# bowling team
# venue
# current score
# balls left
# wickets left
# current run rate
# runs scored in last five overs

# %%
df_new.isnull().sum()
# Out:
# match_id            0
# venue               0
# innings             0
# ball                0
# batting_team        0
# bowling_team        0
# player_dismissed    0
# runs_scored         0
# dtype: int64

# %%
df_new['venue'].value_counts()
# Out:
# Eden Gardens                                                             8657
# Wankhede Stadium                                                         7933
# M Chinnaswamy Stadium                                                    6746
# Feroz Shah Kotla                                                         6386
# Dubai International Cricket Stadium                                      5729
# MA Chidambaram Stadium, Chepauk                                          5484
# Sawai Mansingh Stadium                                                   5338
# Rajiv Gandhi International Stadium, Uppal                                5160
# Wankhede Stadium, Mumbai                                                 4762
# Punjab Cricket Association Stadium, Mohali                               3884
# Sheikh Zayed Stadium                                                     3570
# Sharjah Cricket Stadium                                                  3482
# ...

# %%
df_new.loc[(df_new.venue == 'Eden Gardens'),'venue']='Eden Gardens, Kolkata'
df_new.loc[(df_new.venue == 'Wankhede Stadium'),'venue']='Wankhede Stadium, Mumbai'
df_new.loc[(df_new.venue == 'M Chinnaswamy Stadium'),'venue']='M.Chinnaswamy Stadium, Bengaluru'
df_new.loc[(df_new.venue == 'MA Chidambaram Stadium, Chepauk, Chennai'),'venue']='MA Chidambaram Stadium, Chepauk, Chennai'
df_new.loc[(df_new.venue == 'MA Chidambaram Stadium'),'venue']='MA Chidambaram Stadium, Chepauk, Chennai'
df_new.loc[(df_new.venue == 'Rajiv Gandhi International Stadium, Uppal'),'venue']='Rajiv Gandhi International Stadium, Uppal, Hyderabad'
df_new.loc[(df_new.venue == 'Dr DY Patil Sports Academy, Mumbai'),'venue']='Dr DY Patil Sports Academy'
df_new.loc[(df_new.venue == 'Brabourne Stadium, Mumbai'),'venue']='Brabourne Stadium'
df_new.loc[(df_new.venue == 'Feroz Shah Kotla'),'venue']='Arun Jaitley Stadium, Delhi'
df_new.loc[(df_new.venue == 'Arun Jaitley Stadium'),'venue']='Arun Jaitley Stadium, Delhi'
df_new.loc[(df_new.venue == 'Punjab Cricket Association Stadium, Mohali'),'venue']='Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur'
df_new.loc[(df_new.venue == 'Sardar Patel Stadium, Motera'),'venue']='Narendra Modi Stadium, Ahmedabad'
df_new.loc[(df_new.venue == 'MA Chidambaram Stadium, Chepauk'),'venue']='MA Chidambaram Stadium, Chepauk, Chennai'
df_new.loc[(df_new.venue == 'Narendra Modi Stadium, Ahmedabad'),'venue']='Narendra Modi Stadium, Ahmedabad'
df_new.loc[(df_new.venue == 'Punjab Cricket Association IS Bindra Stadium, Mohali'),'venue']='Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur'
df_new.loc[(df_new.venue == 'Punjab Cricket Association IS Bindra Stadium'),'venue']='Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur'
df_new.loc[(df_new.venue == 'Rajiv Gandhi International Stadium'),'venue']='Rajiv Gandhi International Stadium, Uppal, Hyderabad'
df_new.loc[(df_new.venue == 'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh'),'venue']='Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur'
df_new.loc[(df_new.venue == 'M Chinnaswamy Stadium, Bengaluru'),'venue']='M.Chinnaswamy Stadium, Bengaluru'
df_new.loc[(df_new.venue == 'M.Chinnaswamy Stadium'),'venue']='M.Chinnaswamy Stadium, Bengaluru'
df_new.loc[(df_new.venue == 'Barsapara Cricket Stadium, Guwahati'),'venue']='Barsapara Cricket Stadium, Guwahati'
df_new.loc[(df_new.venue == 'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow'),'venue']='Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow'
df_new.loc[(df_new.venue == 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'),'venue']='Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam'
df_new.loc[(df_new.venue == 'Sawai Mansingh Stadium, Mohali'),'venue']='Sawai Mansingh Stadium, Jaipur'
df_new.loc[(df_new.venue == 'Himachal Pradesh Cricket Association Stadium'),'venue']='Himachal Pradesh Cricket Association Stadium, Dharamsala'

# %%
df
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243812   1370353  Narendra Modi Stadium, Ahmedabad        2  14.2
# 243813   1370353  Narendra Modi Stadium, Ahmedabad        2  14.3
# 243814   1370353  Narendra Modi Stadium, Ahmedabad        2  14.4
# 243815   1370353  Narendra Modi Stadium, Ahmedabad        2  14.5
# 243816   1370353  Narendra Modi Stadium, Ahmedabad        2  14.6
#
#                  batting_team                 bowling_team player_dismissed  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                0
# ...

# %%
df_new['venue'].value_counts()
# Out:
# Wankhede Stadium, Mumbai                                                 12695
# Eden Gardens, Kolkata                                                     9787
# Arun Jaitley Stadium, Delhi                                               9498
# M.Chinnaswamy Stadium, Bengaluru                                          9386
# MA Chidambaram Stadium, Chepauk, Chennai                                  8939
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                      7887
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        6716
# Dubai International Cricket Stadium                                       5729
# Sawai Mansingh Stadium                                                    5338
# Dr DY Patil Sports Academy                                                3723
# Sheikh Zayed Stadium                                                      3570
# Sharjah Cricket Stadium                                                   3482
# ...

# %%
stadiums = ['Wankhede Stadium, Mumbai','Eden Gardens, Kolkata','Arun Jaitley Stadium, Delhi','M.Chinnaswamy Stadium, Bengaluru','MA Chidambaram Stadium, Chepauk, Chennai','Narendra Modi Stadium, Ahmedabad',
           'Rajiv Gandhi International Stadium, Uppal, Hyderabad','Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur','Sawai Mansingh Stadium, Jaipur',
           'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow','Barsapara Cricket Stadium, Guwahati',
            'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium', 'Himachal Pradesh Cricket Association Stadium, Dharamsala']

# %%
df_new = df_new[df_new['venue'].isin(stadiums)]
df_new['venue'].value_counts()
# Out:
# Wankhede Stadium, Mumbai                                                 12695
# Eden Gardens, Kolkata                                                     9787
# Arun Jaitley Stadium, Delhi                                               9498
# M.Chinnaswamy Stadium, Bengaluru                                          9386
# MA Chidambaram Stadium, Chepauk, Chennai                                  8939
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                      7887
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        6716
# Narendra Modi Stadium, Ahmedabad                                          3467
# Himachal Pradesh Cricket Association Stadium, Dharamsala                  1366
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow      859
# Sawai Mansingh Stadium, Jaipur                                             609
# Barsapara Cricket Stadium, Guwahati                                        251
# Name: venue, dtype: int64

# %%
df_new['current_score'] = df_new.groupby('match_id').cumsum()['runs_scored']
# Out:
# <ipython-input-33-87ccd2015030>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_new['current_score'] = df_new.groupby('match_id').cumsum()['runs_scored']
# <ipython-input-33-87ccd2015030>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['current_score'] = df_new.groupby('match_id').cumsum()['runs_scored']

# %%
df_new
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# 1         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.2
# 2         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.3
# 3         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.4
# 4         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# 243719   1370353  Narendra Modi Stadium, Ahmedabad        1  19.3
# 243720   1370353  Narendra Modi Stadium, Ahmedabad        1  19.4
# 243721   1370353  Narendra Modi Stadium, Ahmedabad        1  19.5
# 243722   1370353  Narendra Modi Stadium, Ahmedabad        1  19.6
#
#                  batting_team                 bowling_team player_dismissed  \
# 0       Kolkata Knight Riders  Royal Challengers Bangaluru                0
# ...

# %%
df_new['over'] = df_new['ball'].apply(lambda x:str(x).split(".")[0])
df_new['ball_no'] = df_new['ball'].apply(lambda x:str(x).split(".")[1])
df_new
# Out:
# <ipython-input-35-58f3e06645cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['over'] = df_new['ball'].apply(lambda x:str(x).split(".")[0])
# <ipython-input-35-58f3e06645cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['ball_no'] = df_new['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# ...

# %%
df_new['balls_bowled'] = (df_new['over'].astype('int')*6) + df_new['ball_no'].astype('int')
df_new
# Out:
# <ipython-input-36-a5fe36ef8eaf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['balls_bowled'] = (df_new['over'].astype('int')*6) + df_new['ball_no'].astype('int')
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# 1         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.2
# 2         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.3
# 3         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.4
# 4         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# ...

# %%
df_new['balls_left'] = 120-df_new['balls_bowled']
df_new['balls_left'] = df_new['balls_left'].apply(lambda x:0 if x<0 else x)
df_new
# Out:
# <ipython-input-37-eb079a11211a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['balls_left'] = 120-df_new['balls_bowled']
# <ipython-input-37-eb079a11211a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['balls_left'] = df_new['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# ...

# %%
df_new['player_dismissed'] = df_new['player_dismissed'].apply(lambda x:0 if x==0 else 1)
df_new
# Out:
# <ipython-input-38-a15b5d2cb61c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['player_dismissed'] = df_new['player_dismissed'].apply(lambda x:0 if x==0 else 1)
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# 1         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.2
# 2         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.3
# 3         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.4
# 4         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# ...

# %%
df_new['player_dismissed'] = df_new['player_dismissed'].astype('int')
df_new['player_dismissed'] = df_new.groupby('match_id').cumsum()['player_dismissed']
df_new['wickets_left'] = 10 - df_new['player_dismissed']
# Out:
# <ipython-input-39-52cb09bca02f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['player_dismissed'] = df_new['player_dismissed'].astype('int')
# <ipython-input-39-52cb09bca02f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_new['player_dismissed'] = df_new.groupby('match_id').cumsum()['player_dismissed']
# <ipython-input-39-52cb09bca02f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_new
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# 1         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.2
# 2         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.3
# 3         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.4
# 4         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# 243719   1370353  Narendra Modi Stadium, Ahmedabad        1  19.3
# 243720   1370353  Narendra Modi Stadium, Ahmedabad        1  19.4
# 243721   1370353  Narendra Modi Stadium, Ahmedabad        1  19.5
# 243722   1370353  Narendra Modi Stadium, Ahmedabad        1  19.6
#
#                  batting_team                 bowling_team  player_dismissed  \
# 0       Kolkata Knight Riders  Royal Challengers Bangaluru                 0
# ...

# %%
df_new['current_run_rate'] = (df_new['current_score']*6)/df_new['balls_bowled']
df_new
# Out:
# <ipython-input-41-4382e69babad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['current_run_rate'] = (df_new['current_score']*6)/df_new['balls_bowled']
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# 1         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.2
# 2         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.3
# 3         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.4
# 4         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# ...

# %%
groups = df_new.groupby('match_id')
match_ids = df_new['match_id'].unique()
last_five = []

for id in match_ids:
  last_five.extend(groups.get_group(id).rolling(window = 30).sum()['runs_scored'].values.tolist())
# Out:
# <ipython-input-42-27337c089379>:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'venue'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window = 30).sum()['runs_scored'].values.tolist())

# %%
df_new['last_five'] = last_five
df_new
# Out:
# <ipython-input-43-c86b37741c68>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['last_five'] = last_five
#         match_id                             venue  innings  ball  \
# 0         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.1
# 1         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.2
# 2         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.3
# 3         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.4
# 4         335982  M.Chinnaswamy Stadium, Bengaluru        1   0.5
# ...          ...                               ...      ...   ...
# 243718   1370353  Narendra Modi Stadium, Ahmedabad        1  19.2
# 243719   1370353  Narendra Modi Stadium, Ahmedabad        1  19.3
# ...

# %%
final_df = df_new.groupby('match_id').sum()['runs_scored'].reset_index().merge(df_new,on='match_id')
# Out:
# <ipython-input-44-6c8b3d6d12be>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df_new.groupby('match_id').sum()['runs_scored'].reset_index().merge(df_new,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_scored_x                             venue  innings  \
# 0        335982            222  M.Chinnaswamy Stadium, Bengaluru        1
# 1        335982            222  M.Chinnaswamy Stadium, Bengaluru        1
# 2        335982            222  M.Chinnaswamy Stadium, Bengaluru        1
# 3        335982            222  M.Chinnaswamy Stadium, Bengaluru        1
# 4        335982            222  M.Chinnaswamy Stadium, Bengaluru        1
# ...         ...            ...                               ...      ...
# 71455   1370353            214  Narendra Modi Stadium, Ahmedabad        1
# 71456   1370353            214  Narendra Modi Stadium, Ahmedabad        1
# 71457   1370353            214  Narendra Modi Stadium, Ahmedabad        1
# 71458   1370353            214  Narendra Modi Stadium, Ahmedabad        1
# 71459   1370353            214  Narendra Modi Stadium, Ahmedabad        1
#
#        ball           batting_team                 bowling_team  \
# ...

# %%
final_df=final_df[['batting_team','bowling_team','venue','current_score','balls_left','wickets_left','current_run_rate','last_five','runs_scored_x']]
final_df
# Out:
#                 batting_team                 bowling_team  \
# 0      Kolkata Knight Riders  Royal Challengers Bangaluru
# 1      Kolkata Knight Riders  Royal Challengers Bangaluru
# 2      Kolkata Knight Riders  Royal Challengers Bangaluru
# 3      Kolkata Knight Riders  Royal Challengers Bangaluru
# 4      Kolkata Knight Riders  Royal Challengers Bangaluru
# ...                      ...                          ...
# 71455         Gujarat Titans          Chennai Super Kings
# 71456         Gujarat Titans          Chennai Super Kings
# 71457         Gujarat Titans          Chennai Super Kings
# 71458         Gujarat Titans          Chennai Super Kings
# 71459         Gujarat Titans          Chennai Super Kings
#
#                                   venue  current_score  balls_left  \
# 0      M.Chinnaswamy Stadium, Bengaluru              1         119
# 1      M.Chinnaswamy Stadium, Bengaluru              1         118
# ...

# %%
final_df.dropna(inplace=True)
final_df
# Out:
# <ipython-input-47-09fb923f6a54>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)
#                 batting_team                 bowling_team  \
# 29     Kolkata Knight Riders  Royal Challengers Bangaluru
# 30     Kolkata Knight Riders  Royal Challengers Bangaluru
# 31     Kolkata Knight Riders  Royal Challengers Bangaluru
# 32     Kolkata Knight Riders  Royal Challengers Bangaluru
# 33     Kolkata Knight Riders  Royal Challengers Bangaluru
# ...                      ...                          ...
# 71455         Gujarat Titans          Chennai Super Kings
# 71456         Gujarat Titans          Chennai Super Kings
# 71457         Gujarat Titans          Chennai Super Kings
# 71458         Gujarat Titans          Chennai Super Kings
# ...

# %%
final_df = final_df.sample(final_df.shape[0])
final_df.head()
# Out:
#                       batting_team           bowling_team  \
# 23018          Chennai Super Kings         Delhi Capitals
# 51462  Royal Challengers Bangaluru         Delhi Capitals
# 61931  Royal Challengers Bangaluru   Lucknow Super Giants
# 70013         Lucknow Super Giants         Mumbai Indians
# 40169          Sunrisers Hyderabad  Kolkata Knight Riders
#
#                                                    venue  current_score  \
# 23018                        Arun Jaitley Stadium, Delhi             60
# 51462                   M.Chinnaswamy Stadium, Bengaluru            103
# 61931                              Eden Gardens, Kolkata            116
# 70013  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...             67
# 40169                        Arun Jaitley Stadium, Delhi             43
#
#        balls_left  wickets_left  current_run_rate  last_five  runs_scored_x
# 23018          61             9          6.101695       22.0            169
# ...

# %%
X = final_df.drop(columns=['runs_scored_x'])
y = final_df['runs_scored_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_train
# Out:
#                       batting_team                 bowling_team  \
# 16380  Royal Challengers Bangaluru          Chennai Super Kings
# 44436             Rajasthan Royals          Sunrisers Hyderabad
# 51368               Mumbai Indians          Sunrisers Hyderabad
# 10302                 Punjab Kings          Chennai Super Kings
# 54076               Delhi Capitals  Royal Challengers Bangaluru
# ...                            ...                          ...
# 40671        Kolkata Knight Riders               Mumbai Indians
# 2765         Kolkata Knight Riders  Royal Challengers Bangaluru
# 2668                Delhi Capitals          Chennai Super Kings
# 5672                  Punjab Kings          Chennai Super Kings
# 23200                 Punjab Kings          Sunrisers Hyderabad
#
#                                                    venue  current_score  \
# 16380           MA Chidambaram Stadium, Chepauk, Chennai            150
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','venue'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=10))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.956333943946992
# 3.2511131041683257

# %%
X_test
# Out:
#                       batting_team                 bowling_team  \
# 69628  Royal Challengers Bangaluru             Rajasthan Royals
# 57078               Mumbai Indians               Delhi Capitals
# 23362             Rajasthan Royals  Royal Challengers Bangaluru
# 26442               Mumbai Indians             Rajasthan Royals
# 7446           Sunrisers Hyderabad             Rajasthan Royals
# ...                            ...                          ...
# 8027   Royal Challengers Bangaluru          Chennai Super Kings
# 68955  Royal Challengers Bangaluru               Mumbai Indians
# 14003                 Punjab Kings               Mumbai Indians
# 22987          Chennai Super Kings               Delhi Capitals
# 9940                  Punjab Kings          Sunrisers Hyderabad
#
#                                                    venue  current_score  \
# 69628                     Sawai Mansingh Stadium, Jaipur             61
# ...

# %%
pipe.predict(X_test)
# Out:
# array([169.79253, 137.32713, 117.34318, ..., 164.47673, 158.57428,
#        174.30423], dtype=float32)

# %%
pipe.score(X_test,y_test)
# Out:
# 0.956333943946992

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
pipe1 = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',Ridge(alpha=0.0001,random_state=10))
])

# %%
pipe1.fit(X_train,y_train)
y_pred1 = pipe1.predict(X_test)
print(r2_score(y_test,y_pred1))
print(mean_absolute_error(y_test,y_pred1))
# Out:
# 0.6474457405528883
# 13.415143623026687
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
pipe1.score(X_test,y_test)
# Out:
# 0.6474457405528883

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipe2 = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',RandomForestClassifier(n_estimators=40))
])

# %%
pipe2.fit(X_train,y_train)
y_pred2 = pipe1.predict(X_test)
print(r2_score(y_test,y_pred2))
print(mean_absolute_error(y_test,y_pred2))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.6474457405528883
# 13.415143623026687

# %%
from sklearn.svm import SVC

# %%
pipe3 = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',SVC(C=10,gamma=10,kernel='linear'))
])

# %%
pipe3.fit(X_train,y_train)
y_pred3 = pipe3.predict(X_test)
print(r2_score(y_test,y_pred3))
print(mean_absolute_error(y_test,y_pred3))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.8976001483889465
# 2.75311279296875

# %%
from sklearn import tree

# %%
pipe4 = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',tree.DecisionTreeClassifier())
])

# %%
pipe4.fit(X_train,y_train)
y_pred4 = pipe4.predict(X_test)
print(r2_score(y_test,y_pred4))
print(mean_absolute_error(y_test,y_pred4))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9347299080670745
# 1.51025390625

# %% [markdown]
# Highest Accuracy is obtained in XGBRegressor

# %%
# import pickle

# %%
# pickle.dump(pipe,open('model.pkl','wb'))
